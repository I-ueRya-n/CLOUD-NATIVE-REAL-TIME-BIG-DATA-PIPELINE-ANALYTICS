# %% [markdown]
# ## Reviews from the Google Places API
#
# ### get_place_id
# returns a list of (default 1 item) place ids from a list of search terms "details_list"
# This may be useful for getting details e.g. locations, names from a post
#
# Run this as many times as you like, its free!
#
# ### get_place_info
# returns the place's name, place/food types and (if getting reviews), its star rating and reviews
#
# THIS IS A LIMITED RESOURCE, DONT RUN THIS A LOT
# Triggers the: "Places API Place Details Enterprise + Atmosphere" SKU
#   (which has a limit of 1000 free requests per month and is ridiculously expensive after that.)
#
# ### to run this file
# Make a .env with GOOGLE_PLACES_API_KEY=<your key>
#
# ### intergration into the overall system
# bro idk.
#
# ### other thoughts
# happy to change anything.
# This..... may not be the best option if we need large amounts of data.
# I will keep looking for other ways to get reviews that are... cheaper. yay!

# %%
import requests

def get_place_id(details_list, api_key, num_results=1):
  """
  Takes a list of details (e.g., address, name, etc.) and an API key,
  and returns a list of place IDs, sorted by closest match.
  Triggers the: "Places API Text Search Essentials (IDs Only)" SKU
  which has unlimited usage. yay!
  """
  base_url = "https://places.googleapis.com/v1/places:searchText"
  details = ", ".join(details_list)

  headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': api_key,
    'X-Goog-FieldMask': 'places.id,places.name',
  }
  json_data = {
    'textQuery' : details,
  }
    
  response = requests.post(base_url, headers=headers, json=json_data)

  if response.status_code == 200:
    ids = []
    for place in response.json()['places']:
      print("Possible place found:", place['id'])
      ids.append(place['id'])
    return ids
  else:
    print("Error:", response.status_code, response.text)
    return None  
  
def get_place_info(place_id, api_key, get_reviews=True):
  """
  Takes a place ID and an API key, and returns place information.

  if get_reviews is True, it will also return reviews and a rating:
  Triggers the: "Places API Place Details Enterprise + Atmosphere" SKU
  (which has a limit of 1000 free requests per month and is ridiculously 
  expensive after that.)

  if get_reviews is False:
  Triggers the: "Places API Place Details Pro" SKU
  (which has a limit of 5000 free requests per month)
  """
  base_url = "https://places.googleapis.com/v1/places/"

  fields = "id,displayName,types"
  if get_reviews:
    fields += ",rating,reviews"
  headers = {
    'Content-Type': 'application/json',
    'X-Goog-Api-Key': api_key,
    'X-Goog-FieldMask': fields,
  }
  response = requests.get(base_url + place_id, headers=headers)

  if response.status_code == 200:
    json_response = response.json()
    print("Place found:", json_response['displayName'])
    print("Food types:", json_response['types'])

    if get_reviews:
      print("Rating:", json_response['rating'])
      print("Reviews:", json_response['reviews'])

    return json_response
  else:
    print("Error:", response.status_code, response.text)
    return None

# %%
## just getting the API key from the .env file
from dotenv import load_dotenv
import os
load_dotenv()

api_key = os.getenv("GOOGLE_PLACES_API_KEY")

# %%
sample_place_id = get_place_id(['Green refectory', 'brunswick'], api_key)
print(sample_place_id)
# Out:
# Possible place found: ChIJPTuHr8pc1moRiVeBM4pebMw
# ['ChIJPTuHr8pc1moRiVeBM4pebMw']

# %%
## Sample output of whole json response:
# EXPENSIVE, DONT RUN THIS TOO OFTEN
if sample_place_id:
  place_info = get_place_info(sample_place_id[0], api_key, get_reviews=True)
# Out:
# Place found: {'text': 'Green Refectory', 'languageCode': 'en'}
# Food types: ['cafe', 'vegetarian_restaurant', 'coffee_shop', 'breakfast_restaurant', 'food_store', 'store', 'restaurant', 'food', 'point_of_interest', 'establishment']
# Rating: 4.5
# ...

# %%
## Sample output of whole json response:
print(place_info)
# Out:
# {'id': 'ChIJPTuHr8pc1moRiVeBM4pebMw', 'types': ['cafe', 'vegetarian_restaurant', 'breakfast_restaurant', 'coffee_shop', 'food_store', 'store', 'restaurant', 'point_of_interest', 'food', 'establishment'], 'rating': 4.5, 'displayName': {'text': 'Green Refectory', 'languageCode': 'en'}, 'reviews': [{'name': 'places/ChIJPTuHr8pc1moRiVeBM4pebMw/reviews/ChZDSUhNMG9nS0VJQ0FnTUNBMnNhLU9nEAE', 'relativePublishTimeDescription': '2 months ago', 'rating': 5, 'text': {'text': 'Excellent value for money. Huge choice of meal options. Nice lane seating (quite limited) so you may not find a seat easily. Good coffee and friendly staff. My go to place on Sydney Road.', 'languageCode': 'en'}, 'originalText': {'text': 'Excellent value for money. Huge choice of meal options. Nice lane seating (quite limited) so you may not find a seat easily. Good coffee and friendly staff. My go to place on Sydney Road.', 'languageCode': 'en'}, 'authorAttribution': {'displayName': 'Juergen Bowe', 'uri': 'https://www.goog
# ...
